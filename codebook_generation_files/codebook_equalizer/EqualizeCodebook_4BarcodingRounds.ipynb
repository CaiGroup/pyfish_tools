# %% [markdown]
# ### Equalizing Codebook, 4 barcoding rounds
# #### Author: Arun Chakravorty
# ##### Purpose: An algorithm that generates a codebook that has maximally equalized expression across all hybs.

# %%
from FPKM_Equalizing_4BarcodingRounds import *

# %% [markdown]
# ### 1. Obtaining FPKM per gene
#
# Only run this if you need to pair genes you want with their expression. If the gene is not present in the expression table, the expression will be set to 0. Otherwise, start from 2(Creating Codebook) directly.

# %%
# Load in dataframe containing genes and expression per gene
# Make sure the column heading is `gene_symbols` and `avg`
max_tpm = pd.read_csv('ExampleFiles/max_tpm_ensemble.csv')
max_tpm = max_tpm.rename(columns={'Unnamed: 0': 'gene_symbols', 'TPM': 'avg'})
max_tpm.head()
# Out:
#          gene_symbols         avg
# 0  ENSMUSG00000007777   31.121931
# 1  ENSMUSG00000042208   13.532153
# 2  ENSMUSG00000020831  149.176683
# 3  ENSMUSG00000107002   50.394900
# 4  ENSMUSG00000058706    4.861402

# %%
# Load in the different genes per channel. 
# Code will pair 'ensemble id' with the expression found under `gene_symbols` in the max_tpm table. 
# Choosing 645 genes to fit within 9^4 with parity check. 

channel1 = pd.read_csv('ExampleFiles/channel1_genes.csv')[5:650]
channel2 = pd.read_csv('ExampleFiles/channel2_genes.csv')[5:650]
channel3 = pd.read_csv('ExampleFiles/channel3_genes.csv')[5:650]

# %%
channel1.head()
# Out:
#    Unnamed: 0         ensemble id gene sym
# 5           5  ENSMUSG00000057278    Snrpg
# 6           6  ENSMUSG00000026069   Il1rl1
# 7           7  ENSMUSG00000029304     Spp1
# 8           8  ENSMUSG00000011752    Pgam1
# 9           9  ENSMUSG00000090553    Snrpe

# %%
# Obtain FPKMS per gene 
Channel1FPKMS = getFPKMS(channel1, max_tpm)
Channel1FPKMS.head()
# Out:
#          gene_symbols          avg
# 0  ENSMUSG00000057278  1003.753300
# 1  ENSMUSG00000026069   975.897425
# 2  ENSMUSG00000029304   902.313874
# 3  ENSMUSG00000011752   816.437780
# 4  ENSMUSG00000090553   782.729194

# %% [markdown]
# ### 2. Creating Codebook.
#
# You may start from here if you already have a dataframe of genes and average expression for each. Simply make sure the columns are `gene_symbols` and `avg` like the dataframe above. **IMPORTANT** Make sure the dataframe is sorted by order of expression.
#
# Parameters: # of pseudocolors, FPKM dataframe(must have columns as 'gene_symbols' and 'avg')

# %%
'''
Inputs
pc - Integer number of pseudocolors in codebook design.
FPKMS - Pandas dataframe containing the genes under 'gene_symbols', and the expression value under 'avg'.

Returns a pandas dataframe containing all genes and their barcode assignment.
'''

Channel1Codebook = GenerateCodebook(9, Channel1FPKMS)
# Out:
# Created empty codebook
# Assigned Highest Expressing Genes
# RemainingCodebook Length 720
# [8, 8, 3, 1]
# 1
# RemainingCodebook Length 719
# [9, 9, 9, 9]
# 2
# RemainingCodebook Length 718
# [5, 1, 1, 7]
# 3
# RemainingCodebook Length 717
# [7, 6, 1, 5]
# 4
# RemainingCodebook Length 716
# [6, 5, 6, 8]
# 5
# RemainingCodebook Length 715
# [2, 1, 8, 2]
# 6
# RemainingCodebook Length 714
# [1, 7, 3, 2]
# 7
# RemainingCodebook Length 713
# [5, 3, 5, 4]
# 8
# RemainingCodebook Length 712
# [3, 7, 2, 3]
# 9
# RemainingCodebook Length 711
# [7, 2, 7, 7]
# 10
# RemainingCodebook Length 710
# [8, 4, 2, 5]
# 11
# RemainingCodebook Length 709
# [9, 9, 8, 8]
# 12
# RemainingCodebook Length 708
# [6, 7, 9, 4]
# 13
# RemainingCodebook Length 707
# [7, 6, 4, 8]
# 14
# RemainingCodebook Length 706
# [3, 4, 7, 5]
# 15
# RemainingCodebook Length 705
# [7, 8, 5, 2]
# 16
# RemainingCodebook Length 704
# [4, 3, 9, 7]
# 17
# RemainingCodebook Length 703
# [2, 4, 4, 1]
# 18
# RemainingCodebook Length 702
# [1, 5, 7, 4]
# 19
# RemainingCodebook Length 701
# [4, 9, 8, 3]
# 20
# RemainingCodebook Length 700
# [7, 1, 2, 1]
# 21
# RemainingCodebook Length 699
# [9, 5, 6, 2]
# 22
# RemainingCodebook Length 698
# [8, 3, 6, 8]
# 23
# RemainingCodebook Length 697
# [5, 8, 1, 5]
# 24
# RemainingCodebook Length 696
# [9, 9, 4, 4]
# 25
# RemainingCodebook Length 695
# [6, 6, 7, 1]
# 26
# RemainingCodebook Length 694
# [3, 1, 3, 7]
# 27
# RemainingCodebook Length 693
# [2, 8, 5, 6]
# 28
# RemainingCodebook Length 692
# [1, 6, 6, 4]
# 29
# RemainingCodebook Length 691
# [8, 2, 8, 9]
# 30
# RemainingCodebook Length 690
# [3, 7, 9, 1]
# 31
# RemainingCodebook Length 689
# [4, 2, 1, 7]
# 32
# RemainingCodebook Length 688
# [5, 5, 1, 2]
# 33
# RemainingCodebook Length 687
# [7, 4, 2, 4]
# 34
# RemainingCodebook Length 686
# [6, 8, 5, 1]
# 35
# RemainingCodebook Length 685
# [2, 2, 1, 5]
# 36
# RemainingCodebook Length 684
# [1, 9, 7, 8]
# 37
# RemainingCodebook Length 683
# [6, 3, 2, 2]
# 38
# RemainingCodebook Length 682
# [8, 2, 4, 5]
# 39
# RemainingCodebook Length 681
# [3, 5, 9, 8]
# 40
# RemainingCodebook Length 680
# [5, 7, 4, 7]
# 41
# RemainingCodebook Length 679
# [3, 1, 6, 1]
# 42
# RemainingCodebook Length 678
# [9, 6, 8, 5]
# 43
# RemainingCodebook Length 677
# [2, 3, 8, 4]
# 44
# RemainingCodebook Length 676
# [4, 9, 3, 7]
# 45
# RemainingCodebook Length 675
# [1, 1, 6, 8]
# 46
# RemainingCodebook Length 674
# [4, 2, 7, 4]
# 47
# RemainingCodebook Length 673
# [9, 2, 9, 2]
# 48
# RemainingCodebook Length 672
# [6, 5, 5, 7]
# 49
# RemainingCodebook Length 671
# [4, 5, 5, 5]
# 50
# RemainingCodebook Length 670
# [8, 8, 4, 2]
# 51
# RemainingCodebook Length 669
# [1, 9, 7, 8]
# Adding to i
# 52
# RemainingCodebook Length 668
# [5, 4, 8, 8]
# 53
# RemainingCodebook Length 667
# [2, 7, 5, 5]
# 54
# RemainingCodebook Length 666
# [6, 3, 2, 2]
# Adding to i
# 55
# RemainingCodebook Length 665
# [9, 5, 2, 7]
# 56
# RemainingCodebook Length 664
# [1, 4, 6, 2]
# 57
# RemainingCodebook Length 663
# [4, 9, 6, 1]
# 58
# RemainingCodebook Length 662
# [8, 5, 9, 4]
# 59
# RemainingCodebook Length 661
# [6, 8, 3, 8]
# 60
# RemainingCodebook Length 660
# [3, 4, 4, 2]
# 61
# RemainingCodebook Length 659
# [2, 2, 2, 6]
# 62
# RemainingCodebook Length 658
# [5, 3, 7, 6]
# 63
# RemainingCodebook Length 657
# [9, 2, 3, 5]
# 64
# RemainingCodebook Length 656
# [3, 7, 9, 1]
# Adding to i
# 65
# RemainingCodebook Length 655
# [4, 6, 9, 1]
# 66
# RemainingCodebook Length 654
# [1, 6, 5, 3]
# 67
# RemainingCodebook Length 653
# [3, 3, 4, 1]
# 68
# RemainingCodebook Length 652
# [2, 7, 8, 8]
# 69
# RemainingCodebook Length 651
# [7, 9, 6, 4]
# 70
# RemainingCodebook Length 650
# [8, 9, 3, 2]
# 71
# RemainingCodebook Length 649
# [1, 6, 9, 7]
# 72
# RemainingCodebook Length 648
# [1, 8, 5, 5]
# 73
# RemainingCodebook Length 647
# [5, 7, 7, 1]
# 74
# RemainingCodebook Length 646
# [4, 4, 1, 9]
# 75
# RemainingCodebook Length 645
# [8, 1, 1, 1]
# 76
# RemainingCodebook Length 644
# [9, 8, 5, 4]
# 77
# RemainingCodebook Length 643
# [6, 7, 2, 6]
# 78
# RemainingCodebook Length 642
# [2, 3, 3, 8]
# 79
# RemainingCodebook Length 641
# [7, 4, 1, 3]
# 80
# RemainingCodebook Length 640
# [3, 4, 4, 2]
# Adding to i
# 81
# RemainingCodebook Length 639
# [9, 3, 9, 3]
# 82
# RemainingCodebook Length 638
# [6, 1, 4, 2]
# 83
# RemainingCodebook Length 637
# [3, 9, 4, 7]
# 84
# RemainingCodebook Length 636
# [3, 7, 4, 5]
# 85
# RemainingCodebook Length 635
# [1, 8, 2, 2]
# 86
# RemainingCodebook Length 634
# [8, 3, 3, 5]
# 87
# RemainingCodebook Length 633
# [5, 2, 8, 6]
# 88
# RemainingCodebook Length 632
# [2, 1, 6, 9]
# 89
# RemainingCodebook Length 631
# [2, 6, 8, 7]
# 90
# RemainingCodebook Length 630
# [9, 4, 2, 6]
# 91
# RemainingCodebook Length 629
# [8, 8, 5, 3]
# 92
# RemainingCodebook Length 628
# [6, 6, 7, 1]
# Adding to i
# 93
# RemainingCodebook Length 627
# [3, 7, 8, 9]
# 94
# RemainingCodebook Length 626
# [1, 9, 9, 1]
# 95
# RemainingCodebook Length 625
# [5, 4, 3, 3]
# 96
# RemainingCodebook Length 624
# [6, 6, 5, 8]
# 97
# RemainingCodebook Length 623
# [7, 5, 1, 4]
# 98
# RemainingCodebook Length 622
# [8, 8, 7, 5]
# 99
# RemainingCodebook Length 621
# [1, 2, 8, 2]
# 100
# RemainingCodebook Length 620
# [7, 4, 7, 9]
# 101
# RemainingCodebook Length 619
# [7, 3, 9, 1]
# 102
# RemainingCodebook Length 618
# [4, 8, 4, 7]
# 103
# RemainingCodebook Length 617
# [6, 1, 6, 4]
# 104
# RemainingCodebook Length 616
# [6, 7, 6, 1]
# 105
# RemainingCodebook Length 615
# [4, 9, 3, 7]
# Adding to i
# 106
# RemainingCodebook Length 614
# [5, 9, 9, 5]
# 107
# RemainingCodebook Length 613
# [9, 3, 3, 6]
# 108
# RemainingCodebook Length 612
# [2, 6, 8, 7]
# Adding to i
# 109
# RemainingCodebook Length 611
# [8, 2, 1, 2]
# 110
# RemainingCodebook Length 610
# [7, 7, 2, 7]
# 111
# RemainingCodebook Length 609
# [1, 9, 2, 3]
# 112
# RemainingCodebook Length 608
# [3, 4, 7, 5]
# Adding to i
# 113
# RemainingCodebook Length 607
# [9, 1, 8, 9]
# 114
# RemainingCodebook Length 606
# [6, 6, 5, 8]
# Adding to i
# 115
# RemainingCodebook Length 605
# [4, 5, 5, 5]
# Adding to i
# 116
# RemainingCodebook Length 604
# [8, 5, 7, 2]
# 117
# RemainingCodebook Length 603
# [2, 8, 7, 8]
# 118
# RemainingCodebook Length 602
# [7, 6, 2, 6]
# 119
# RemainingCodebook Length 601
# [4, 9, 8, 3]
# Adding to i
# Adding to i
# 120
# RemainingCodebook Length 600
# [4, 6, 2, 3]
# 121
# RemainingCodebook Length 599
# [5, 4, 9, 9]
# 122
# RemainingCodebook Length 598
# [5, 6, 2, 4]
# 123
# RemainingCodebook Length 597
# [5, 5, 4, 5]
# 124
# RemainingCodebook Length 596
# [1, 9, 5, 6]
# 125
# RemainingCodebook Length 595
# [6, 1, 7, 5]
# 126
# RemainingCodebook Length 594
# [3, 2, 6, 2]
# 127
# RemainingCodebook Length 593
# [7, 7, 2, 7]
# Adding to i
# 128
# RemainingCodebook Length 592
# [2, 6, 1, 9]
# 129
# RemainingCodebook Length 591
# [4, 7, 8, 1]
# 130
# RemainingCodebook Length 590
# [6, 4, 2, 3]
# 131
# RemainingCodebook Length 589
# [3, 3, 5, 2]
# 132
# RemainingCodebook Length 588
# [1, 5, 3, 9]
# 133
# RemainingCodebook Length 587
# [3, 9, 5, 8]
# 134
# RemainingCodebook Length 586
# [9, 7, 6, 4]
# 135
# RemainingCodebook Length 585
# [6, 7, 1, 5]
# 136
# RemainingCodebook Length 584
# [8, 9, 7, 6]
# 137
# RemainingCodebook Length 583
# [7, 1, 2, 1]
# Adding to i
# Adding to i
# 138
# RemainingCodebook Length 582
# [2, 4, 8, 5]
# 139
# RemainingCodebook Length 581
# [1, 6, 9, 7]
# Adding to i
# 140
# RemainingCodebook Length 580
# [4, 6, 3, 4]
# 141
# RemainingCodebook Length 579
# [1, 6, 4, 2]
# 142
# RemainingCodebook Length 578
# [9, 1, 5, 6]
# 143
# RemainingCodebook Length 577
# [5, 1, 6, 3]
# 144
# RemainingCodebook Length 576
# [9, 2, 8, 1]
# 145
# RemainingCodebook Length 575
# [8, 9, 9, 8]
# 146
# RemainingCodebook Length 574
# [2, 3, 4, 9]
# Adding to i
# Adding to i
# 147
# RemainingCodebook Length 573
# [9, 5, 4, 9]
# 148
# RemainingCodebook Length 572
# [4, 7, 5, 7]
# 149
# RemainingCodebook Length 571
# [2, 2, 3, 7]
# 150
# RemainingCodebook Length 570
# [7, 5, 6, 9]
# 151
# RemainingCodebook Length 569
# [3, 7, 6, 7]
# 152
# RemainingCodebook Length 568
# [7, 1, 9, 8]
# 153
# RemainingCodebook Length 567
# [2, 4, 8, 5]
# Adding to i
# 154
# RemainingCodebook Length 566
# [7, 8, 7, 4]
# 155
# RemainingCodebook Length 565
# [6, 9, 8, 5]
# 156
# RemainingCodebook Length 564
# [1, 8, 3, 3]
# 157
# RemainingCodebook Length 563
# [4, 6, 1, 2]
# 158
# RemainingCodebook Length 562
# [3, 4, 4, 2]
# Adding to i
# 159
# RemainingCodebook Length 561
# [3, 2, 9, 5]
# 160
# RemainingCodebook Length 560
# [2, 7, 5, 5]
# Adding to i
# 161
# RemainingCodebook Length 559
# [5, 4, 7, 7]
# 162
# RemainingCodebook Length 558
# [2, 1, 4, 7]
# Adding to i
# Adding to i
# 163
# RemainingCodebook Length 557
# [2, 4, 9, 6]
# 164
# RemainingCodebook Length 556
# [4, 1, 4, 9]
# 165
# RemainingCodebook Length 555
# [6, 6, 8, 2]
# 166
# RemainingCodebook Length 554
# [3, 4, 3, 1]
# Adding to i
# 167
# RemainingCodebook Length 553
# [8, 2, 5, 6]
# 168
# RemainingCodebook Length 552
# [3, 9, 1, 4]
# 169
# RemainingCodebook Length 551
# [2, 3, 3, 8]
# Adding to i
# 170
# RemainingCodebook Length 550
# [8, 5, 6, 1]
# 171
# RemainingCodebook Length 549
# [7, 3, 9, 1]
# Adding to i
# 172
# RemainingCodebook Length 548
# [5, 4, 3, 3]
# Adding to i
# 173
# RemainingCodebook Length 547
# [9, 3, 6, 9]
# 174
# RemainingCodebook Length 546
# [7, 1, 4, 3]
# 175
# RemainingCodebook Length 545
# [5, 7, 5, 8]
# 176
# RemainingCodebook Length 544
# [4, 3, 7, 5]
# 177
# RemainingCodebook Length 543
# [1, 9, 5, 6]
# Adding to i
# 178
# RemainingCodebook Length 542
# [3, 8, 8, 1]
# 179
# RemainingCodebook Length 541
# [3, 4, 9, 7]
# 180
# RemainingCodebook Length 540
# [7, 7, 3, 8]
# 181
# RemainingCodebook Length 539
# [2, 7, 4, 4]
# 182
# RemainingCodebook Length 538
# [1, 1, 8, 1]
# 183
# RemainingCodebook Length 537
# [6, 8, 3, 8]
# Adding to i
# 184
# RemainingCodebook Length 536
# [6, 8, 7, 3]
# 185
# RemainingCodebook Length 535
# [9, 6, 6, 3]
# 186
# RemainingCodebook Length 534
# [4, 7, 2, 4]
# 187
# RemainingCodebook Length 533
# [1, 3, 4, 8]
# 188
# RemainingCodebook Length 532
# [8, 2, 1, 2]
# Adding to i
# 189
# RemainingCodebook Length 531
# [7, 9, 9, 7]
# 190
# RemainingCodebook Length 530
# [8, 9, 3, 2]
# Adding to i
# 191
# RemainingCodebook Length 529
# [9, 1, 1, 2]
# 192
# RemainingCodebook Length 528
# [3, 2, 5, 1]
# 193
# RemainingCodebook Length 527
# [6, 8, 3, 8]
# Adding to i
# 194
# RemainingCodebook Length 526
# [2, 8, 3, 4]
# 195
# RemainingCodebook Length 525
# [5, 7, 6, 9]
# 196
# RemainingCodebook Length 524
# [4, 2, 2, 8]
# 197
# RemainingCodebook Length 523
# [2, 2, 1, 5]
# Adding to i
# Adding to i
# Adding to i
# 198
# RemainingCodebook Length 522
# [8, 5, 3, 7]
# 199
# RemainingCodebook Length 521
# [7, 7, 7, 3]
# 200
# RemainingCodebook Length 520
# [2, 3, 6, 2]
# 201
# RemainingCodebook Length 519
# [1, 4, 9, 5]
# 202
# RemainingCodebook Length 518
# [3, 2, 2, 7]
# 203
# RemainingCodebook Length 517
# [4, 8, 7, 1]
# 204
# RemainingCodebook Length 516
# [6, 3, 8, 8]
# 205
# RemainingCodebook Length 515
# [9, 6, 8, 5]
# Adding to i
# 206
# RemainingCodebook Length 514
# [9, 2, 3, 5]
# Adding to i
# 207
# RemainingCodebook Length 513
# [9, 6, 8, 5]
# Adding to i
# Adding to i
# 208
# RemainingCodebook Length 512
# [7, 7, 4, 9]
# 209
# RemainingCodebook Length 511
# [4, 6, 1, 2]
# Adding to i
# Adding to i
# 210
# RemainingCodebook Length 510
# [9, 4, 9, 4]
# 211
# RemainingCodebook Length 509
# [5, 8, 7, 2]
# 212
# RemainingCodebook Length 508
# [9, 9, 4, 4]
# Adding to i
# 213
# RemainingCodebook Length 507
# [3, 1, 4, 8]
# 214
# RemainingCodebook Length 506
# [6, 9, 6, 3]
# 215
# RemainingCodebook Length 505
# [9, 3, 7, 1]
# 216
# RemainingCodebook Length 504
# [1, 9, 8, 9]
# 217
# RemainingCodebook Length 503
# [4, 8, 2, 5]
# 218
# RemainingCodebook Length 502
# [3, 5, 3, 2]
# 219
# RemainingCodebook Length 501
# [8, 1, 4, 4]
# 220
# RemainingCodebook Length 500
# [1, 6, 5, 3]
# Adding to i
# Adding to i
# 221
# RemainingCodebook Length 499
# [5, 6, 5, 7]
# 222
# RemainingCodebook Length 498
# [7, 6, 5, 9]
# 223
# RemainingCodebook Length 497
# [6, 2, 6, 5]
# 224
# RemainingCodebook Length 496
# [8, 2, 9, 1]
# 225
# RemainingCodebook Length 495
# [9, 3, 8, 2]
# 226
# RemainingCodebook Length 494
# [7, 2, 1, 1]
# 227
# RemainingCodebook Length 493
# [1, 9, 3, 4]
# 228
# RemainingCodebook Length 492
# [9, 5, 2, 7]
# Adding to i
# Adding to i
# Adding to i
# 229
# RemainingCodebook Length 491
# [1, 4, 1, 6]
# 230
# RemainingCodebook Length 490
# [5, 3, 4, 3]
# 231
# RemainingCodebook Length 489
# [8, 8, 2, 9]
# 232
# RemainingCodebook Length 488
# [4, 6, 6, 7]
# 233
# RemainingCodebook Length 487
# [6, 4, 1, 2]
# 234
# RemainingCodebook Length 486
# [7, 5, 7, 1]
# 235
# RemainingCodebook Length 485
# [2, 8, 4, 5]
# 236
# RemainingCodebook Length 484
# [2, 9, 5, 7]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 237
# RemainingCodebook Length 483
# [2, 3, 2, 7]
# 238
# RemainingCodebook Length 482
# [3, 2, 7, 3]
# 239
# RemainingCodebook Length 481
# [9, 9, 8, 8]
# Adding to i
# 240
# RemainingCodebook Length 480
# [1, 6, 5, 3]
# Adding to i
# 241
# RemainingCodebook Length 479
# [1, 9, 8, 9]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 242
# RemainingCodebook Length 478
# [5, 9, 6, 2]
# 243
# RemainingCodebook Length 477
# [9, 6, 8, 5]
# Adding to i
# 244
# RemainingCodebook Length 476
# [1, 5, 4, 1]
# 245
# RemainingCodebook Length 475
# [9, 4, 1, 5]
# 246
# RemainingCodebook Length 474
# [7, 3, 8, 9]
# 247
# RemainingCodebook Length 473
# [6, 7, 5, 9]
# 248
# RemainingCodebook Length 472
# [3, 2, 7, 3]
# Adding to i
# Adding to i
# 249
# RemainingCodebook Length 471
# [2, 3, 7, 3]
# 250
# RemainingCodebook Length 470
# [8, 1, 2, 2]
# 251
# RemainingCodebook Length 469
# [5, 2, 6, 4]
# 252
# RemainingCodebook Length 468
# [7, 5, 3, 6]
# 253
# RemainingCodebook Length 467
# [2, 9, 3, 5]
# 254
# RemainingCodebook Length 466
# [4, 8, 5, 8]
# 255
# RemainingCodebook Length 465
# [8, 1, 7, 7]
# 256
# RemainingCodebook Length 464
# [1, 7, 4, 3]
# Adding to i
# 257
# RemainingCodebook Length 463
# [3, 6, 1, 1]
# 258
# RemainingCodebook Length 462
# [4, 7, 4, 6]
# 259
# RemainingCodebook Length 461
# [5, 4, 2, 2]
# 260
# RemainingCodebook Length 460
# [9, 2, 8, 1]
# Adding to i
# 261
# RemainingCodebook Length 459
# [8, 6, 8, 4]
# 262
# RemainingCodebook Length 458
# [3, 9, 9, 3]
# 263
# RemainingCodebook Length 457
# [6, 4, 7, 8]
# 264
# RemainingCodebook Length 456
# [2, 2, 9, 4]
# 265
# RemainingCodebook Length 455
# [9, 3, 4, 7]
# 266
# RemainingCodebook Length 454
# [6, 8, 1, 6]
# 267
# RemainingCodebook Length 453
# [1, 7, 2, 1]
# 268
# RemainingCodebook Length 452
# [7, 8, 5, 2]
# Adding to i
# Adding to i
# 269
# RemainingCodebook Length 451
# [6, 1, 5, 3]
# 270
# RemainingCodebook Length 450
# [8, 2, 4, 5]
# Adding to i
# Adding to i
# 271
# RemainingCodebook Length 449
# [7, 9, 3, 1]
# 272
# RemainingCodebook Length 448
# [4, 4, 6, 5]
# 273
# RemainingCodebook Length 447
# [7, 2, 4, 4]
# 274
# RemainingCodebook Length 446
# [5, 2, 9, 7]
# 275
# RemainingCodebook Length 445
# [5, 6, 4, 6]
# 276
# RemainingCodebook Length 444
# [1, 7, 6, 5]
# 277
# RemainingCodebook Length 443
# [1, 3, 7, 2]
# 278
# RemainingCodebook Length 442
# [6, 4, 1, 2]
# Adding to i
# Adding to i
# Adding to i
# 279
# RemainingCodebook Length 441
# [7, 1, 1, 9]
# 280
# RemainingCodebook Length 440
# [6, 8, 5, 1]
# Adding to i
# 281
# RemainingCodebook Length 439
# [6, 8, 6, 2]
# 282
# RemainingCodebook Length 438
# [4, 3, 5, 3]
# 283
# RemainingCodebook Length 437
# [3, 3, 7, 4]
# 284
# RemainingCodebook Length 436
# [6, 9, 9, 6]
# 285
# RemainingCodebook Length 435
# [3, 2, 8, 4]
# 286
# RemainingCodebook Length 434
# [9, 9, 8, 8]
# Adding to i
# Adding to i
# 287
# RemainingCodebook Length 433
# [2, 9, 1, 3]
# 288
# RemainingCodebook Length 432
# [9, 7, 3, 1]
# 289
# RemainingCodebook Length 431
# [3, 6, 2, 2]
# 290
# RemainingCodebook Length 430
# [8, 1, 5, 5]
# 291
# RemainingCodebook Length 429
# [4, 3, 1, 8]
# Adding to i
# 292
# RemainingCodebook Length 428
# [9, 1, 9, 1]
# 293
# RemainingCodebook Length 427
# [4, 7, 5, 7]
# Adding to i
# 294
# RemainingCodebook Length 426
# [2, 7, 1, 1]
# 295
# RemainingCodebook Length 425
# [8, 2, 8, 9]
# Adding to i
# 296
# RemainingCodebook Length 424
# [1, 6, 9, 7]
# Adding to i
# 297
# RemainingCodebook Length 423
# [7, 6, 4, 8]
# Adding to i
# Adding to i
# Adding to i
# 298
# RemainingCodebook Length 422
# [6, 1, 4, 2]
# Adding to i
# Adding to i
# 299
# RemainingCodebook Length 421
# [2, 4, 6, 3]
# 300
# RemainingCodebook Length 420
# [6, 1, 7, 5]
# Adding to i
# 301
# RemainingCodebook Length 419
# [6, 3, 9, 9]
# 302
# RemainingCodebook Length 418
# [4, 2, 5, 2]
# 303
# RemainingCodebook Length 417
# [7, 7, 2, 7]
# Adding to i
# Adding to i
# 304
# RemainingCodebook Length 416
# [7, 7, 8, 4]
# 305
# RemainingCodebook Length 415
# [8, 8, 1, 8]
# 306
# RemainingCodebook Length 414
# [3, 9, 2, 5]
# 307
# RemainingCodebook Length 413
# [6, 4, 2, 3]
# Adding to i
# 308
# RemainingCodebook Length 412
# [4, 4, 6, 5]
# Adding to i
# 309
# RemainingCodebook Length 411
# [3, 6, 6, 6]
# Adding to i
# 310
# RemainingCodebook Length 410
# [1, 2, 4, 7]
# 311
# RemainingCodebook Length 409
# [3, 7, 6, 7]
# Adding to i
# Adding to i
# Adding to i
# 312
# RemainingCodebook Length 408
# [2, 4, 9, 6]
# Adding to i
# Adding to i
# Adding to i
# 313
# RemainingCodebook Length 407
# [5, 9, 8, 4]
# 314
# RemainingCodebook Length 406
# [9, 7, 8, 6]
# 315
# RemainingCodebook Length 405
# [6, 4, 1, 2]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 316
# RemainingCodebook Length 404
# [8, 6, 1, 6]
# 317
# RemainingCodebook Length 403
# [7, 4, 7, 9]
# Adding to i
# Adding to i
# 318
# RemainingCodebook Length 402
# [9, 7, 6, 4]
# Adding to i
# 319
# RemainingCodebook Length 401
# [1, 4, 5, 1]
# 320
# RemainingCodebook Length 400
# [3, 3, 7, 4]
# Adding to i
# 321
# RemainingCodebook Length 399
# [3, 3, 5, 2]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 322
# RemainingCodebook Length 398
# [5, 3, 3, 2]
# 323
# RemainingCodebook Length 397
# [2, 4, 7, 4]
# 324
# RemainingCodebook Length 396
# [6, 2, 1, 9]
# 325
# RemainingCodebook Length 395
# [5, 6, 4, 6]
# Adding to i
# 326
# RemainingCodebook Length 394
# [7, 6, 6, 1]
# 327
# RemainingCodebook Length 393
# [4, 9, 4, 8]
# 328
# RemainingCodebook Length 392
# [1, 7, 7, 6]
# 329
# RemainingCodebook Length 391
# [3, 9, 9, 3]
# Adding to i
# Adding to i
# 330
# RemainingCodebook Length 390
# [3, 2, 6, 2]
# Adding to i
# Adding to i
# 331
# RemainingCodebook Length 389
# [3, 5, 4, 3]
# 332
# RemainingCodebook Length 388
# [2, 9, 5, 7]
# Adding to i
# Adding to i
# 333
# RemainingCodebook Length 387
# [2, 3, 2, 7]
# Adding to i
# 334
# RemainingCodebook Length 386
# [9, 1, 1, 2]
# Adding to i
# 335
# RemainingCodebook Length 385
# [7, 3, 2, 3]
# 336
# RemainingCodebook Length 384
# [6, 1, 3, 1]
# 337
# RemainingCodebook Length 383
# [9, 7, 8, 6]
# Adding to i
# 338
# RemainingCodebook Length 382
# [3, 9, 1, 4]
# Adding to i
# Adding to i
# Adding to i
# 339
# RemainingCodebook Length 381
# [2, 2, 9, 4]
# Adding to i
# Adding to i
# 340
# RemainingCodebook Length 380
# [2, 9, 7, 9]
# 341
# RemainingCodebook Length 379
# [8, 2, 2, 3]
# 342
# RemainingCodebook Length 378
# [8, 6, 1, 6]
# Adding to i
# Adding to i
# 343
# RemainingCodebook Length 377
# [6, 8, 8, 4]
# 344
# RemainingCodebook Length 376
# [5, 6, 4, 6]
# Adding to i
# 345
# RemainingCodebook Length 375
# [9, 6, 1, 7]
# 346
# RemainingCodebook Length 374
# [7, 7, 5, 1]
# 347
# RemainingCodebook Length 373
# [8, 5, 4, 8]
# 348
# RemainingCodebook Length 372
# [1, 5, 9, 6]
# 349
# RemainingCodebook Length 371
# [5, 9, 1, 6]
# Adding to i
# 350
# RemainingCodebook Length 370
# [6, 3, 2, 2]
# Adding to i
# 351
# RemainingCodebook Length 369
# [7, 6, 2, 6]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 352
# RemainingCodebook Length 368
# [1, 3, 7, 2]
# Adding to i
# 353
# RemainingCodebook Length 367
# [4, 9, 2, 6]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 354
# RemainingCodebook Length 366
# [6, 9, 9, 6]
# Adding to i
# Adding to i
# Adding to i
# 355
# RemainingCodebook Length 365
# [1, 7, 8, 7]
# 356
# RemainingCodebook Length 364
# [5, 9, 3, 8]
# 357
# RemainingCodebook Length 363
# [6, 1, 4, 2]
# Adding to i
# Adding to i
# Adding to i
# 358
# RemainingCodebook Length 362
# [6, 5, 4, 6]
# 359
# RemainingCodebook Length 361
# [2, 5, 4, 2]
# 360
# RemainingCodebook Length 360
# [7, 8, 5, 2]
# Adding to i
# 361
# RemainingCodebook Length 359
# [3, 6, 5, 5]
# 362
# RemainingCodebook Length 358
# [9, 8, 3, 2]
# 363
# RemainingCodebook Length 357
# [3, 3, 7, 4]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 364
# RemainingCodebook Length 356
# [9, 1, 8, 9]
# Adding to i
# 365
# RemainingCodebook Length 355
# [4, 3, 5, 3]
# Adding to i
# Adding to i
# Adding to i
# 366
# RemainingCodebook Length 354
# [5, 7, 5, 8]
# Adding to i
# 367
# RemainingCodebook Length 353
# [2, 7, 9, 9]
# 368
# RemainingCodebook Length 352
# [4, 2, 1, 7]
# Adding to i
# Adding to i
# 369
# RemainingCodebook Length 351
# [7, 3, 8, 9]
# Adding to i
# Adding to i
# 370
# RemainingCodebook Length 350
# [6, 2, 6, 5]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 371
# RemainingCodebook Length 349
# [5, 5, 8, 9]
# 372
# RemainingCodebook Length 348
# [8, 8, 7, 5]
# Adding to i
# Adding to i
# 373
# RemainingCodebook Length 347
# [8, 3, 2, 4]
# 374
# RemainingCodebook Length 346
# [5, 6, 1, 3]
# 375
# RemainingCodebook Length 345
# [7, 7, 9, 5]
# 376
# RemainingCodebook Length 344
# [1, 8, 1, 1]
# 377
# RemainingCodebook Length 343
# [9, 9, 5, 5]
# 378
# RemainingCodebook Length 342
# [2, 1, 5, 8]
# 379
# RemainingCodebook Length 341
# [3, 8, 4, 6]
# 380
# RemainingCodebook Length 340
# [6, 3, 9, 9]
# Adding to i
# 381
# RemainingCodebook Length 339
# [4, 3, 6, 4]
# 382
# RemainingCodebook Length 338
# [3, 4, 9, 7]
# Adding to i
# Adding to i
# 383
# RemainingCodebook Length 337
# [5, 4, 9, 9]
# Adding to i
# Adding to i
# 384
# RemainingCodebook Length 336
# [1, 5, 3, 9]
# Adding to i
# 385
# RemainingCodebook Length 335
# [3, 6, 8, 8]
# Adding to i
# 386
# RemainingCodebook Length 334
# [1, 2, 9, 3]
# 387
# RemainingCodebook Length 333
# [3, 6, 5, 5]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 388
# RemainingCodebook Length 332
# [2, 8, 8, 9]
# 389
# RemainingCodebook Length 331
# [9, 8, 8, 7]
# Adding to i
# 390
# RemainingCodebook Length 330
# [2, 6, 6, 5]
# 391
# RemainingCodebook Length 329
# [8, 4, 1, 4]
# Adding to i
# Adding to i
# 392
# RemainingCodebook Length 328
# [9, 3, 3, 6]
# Adding to i
# Adding to i
# 393
# RemainingCodebook Length 327
# [9, 7, 8, 6]
# Adding to i
# Adding to i
# 394
# RemainingCodebook Length 326
# [5, 5, 8, 9]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 395
# RemainingCodebook Length 325
# [6, 5, 4, 6]
# Adding to i
# Adding to i
# Adding to i
# 396
# RemainingCodebook Length 324
# [8, 8, 1, 8]
# Adding to i
# 397
# RemainingCodebook Length 323
# [7, 9, 8, 6]
# 398
# RemainingCodebook Length 322
# [3, 6, 8, 8]
# Adding to i
# Adding to i
# 399
# RemainingCodebook Length 321
# [3, 7, 3, 4]
# 400
# RemainingCodebook Length 320
# [2, 4, 6, 3]
# Adding to i
# Adding to i
# 401
# RemainingCodebook Length 319
# [8, 4, 5, 8]
# Adding to i
# Adding to i
# Adding to i
# 402
# RemainingCodebook Length 318
# [1, 6, 3, 1]
# 403
# RemainingCodebook Length 317
# [6, 3, 2, 2]
# Adding to i
# 404
# RemainingCodebook Length 316
# [9, 3, 1, 4]
# 405
# RemainingCodebook Length 315
# [6, 6, 4, 7]
# 406
# RemainingCodebook Length 314
# [8, 5, 8, 3]
# 407
# RemainingCodebook Length 313
# [4, 9, 2, 6]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 408
# RemainingCodebook Length 312
# [8, 1, 8, 8]
# 409
# RemainingCodebook Length 311
# [7, 3, 5, 6]
# 410
# RemainingCodebook Length 310
# [3, 2, 9, 5]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 411
# RemainingCodebook Length 309
# [2, 9, 6, 8]
# 412
# RemainingCodebook Length 308
# [9, 9, 9, 9]
# Adding to i
# 413
# RemainingCodebook Length 307
# [3, 2, 2, 7]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 414
# RemainingCodebook Length 306
# [7, 2, 9, 9]
# 415
# RemainingCodebook Length 305
# [6, 6, 2, 5]
# 416
# RemainingCodebook Length 304
# [9, 8, 3, 2]
# Adding to i
# 417
# RemainingCodebook Length 303
# [4, 4, 4, 3]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 418
# RemainingCodebook Length 302
# [4, 8, 9, 3]
# 419
# RemainingCodebook Length 301
# [4, 7, 7, 9]
# 420
# RemainingCodebook Length 300
# [9, 2, 3, 5]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 421
# RemainingCodebook Length 299
# [3, 9, 7, 1]
# 422
# RemainingCodebook Length 298
# [9, 5, 6, 2]
# Adding to i
# 423
# RemainingCodebook Length 297
# [3, 7, 2, 3]
# Adding to i
# Adding to i
# 424
# RemainingCodebook Length 296
# [9, 6, 3, 9]
# 425
# RemainingCodebook Length 295
# [3, 1, 8, 3]
# 426
# RemainingCodebook Length 294
# [6, 5, 4, 6]
# Adding to i
# Adding to i
# 427
# RemainingCodebook Length 293
# [5, 3, 7, 6]
# Adding to i
# Adding to i
# 428
# RemainingCodebook Length 292
# [2, 3, 3, 8]
# Adding to i
# Adding to i
# Adding to i
# 429
# RemainingCodebook Length 291
# [3, 2, 3, 8]
# 430
# RemainingCodebook Length 290
# [5, 7, 1, 4]
# 431
# RemainingCodebook Length 289
# [8, 5, 1, 5]
# Adding to i
# Adding to i
# Adding to i
# 432
# RemainingCodebook Length 288
# [9, 5, 3, 8]
# Adding to i
# Adding to i
# 433
# RemainingCodebook Length 287
# [9, 2, 8, 1]
# Adding to i
# 434
# RemainingCodebook Length 286
# [4, 5, 1, 1]
# 435
# RemainingCodebook Length 285
# [1, 3, 8, 3]
# 436
# RemainingCodebook Length 284
# [4, 1, 6, 2]
# 437
# RemainingCodebook Length 283
# [8, 8, 5, 3]
# Adding to i
# Adding to i
# 438
# RemainingCodebook Length 282
# [2, 6, 2, 1]
# Adding to i
# 439
# RemainingCodebook Length 281
# [5, 1, 3, 9]
# 440
# RemainingCodebook Length 280
# [8, 3, 3, 5]
# Adding to i
# 441
# RemainingCodebook Length 279
# [4, 6, 4, 5]
# Adding to i
# Adding to i
# Adding to i
# 442
# RemainingCodebook Length 278
# [2, 5, 4, 2]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 443
# RemainingCodebook Length 277
# [3, 5, 4, 3]
# Adding to i
# Adding to i
# Adding to i
# 444
# RemainingCodebook Length 276
# [1, 3, 1, 5]
# Adding to i
# 445
# RemainingCodebook Length 275
# [1, 5, 6, 3]
# 446
# RemainingCodebook Length 274
# [9, 3, 8, 2]
# Adding to i
# Adding to i
# Adding to i
# 447
# RemainingCodebook Length 273
# [9, 1, 1, 2]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 448
# RemainingCodebook Length 272
# [8, 5, 6, 1]
# Adding to i
# Adding to i
# Adding to i
# 449
# RemainingCodebook Length 271
# [8, 5, 5, 9]
# Adding to i
# 450
# RemainingCodebook Length 270
# [1, 7, 3, 2]
# Adding to i
# Adding to i
# Adding to i
# 451
# RemainingCodebook Length 269
# [1, 7, 1, 9]
# 452
# RemainingCodebook Length 268
# [9, 8, 6, 5]
# 453
# RemainingCodebook Length 267
# [8, 4, 4, 7]
# Adding to i
# Adding to i
# Adding to i
# 454
# RemainingCodebook Length 266
# [4, 1, 1, 6]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 455
# RemainingCodebook Length 265
# [8, 2, 7, 8]
# 456
# RemainingCodebook Length 264
# [4, 5, 5, 5]
# Adding to i
# Adding to i
# Adding to i
# 457
# RemainingCodebook Length 263
# [4, 2, 5, 2]
# Adding to i
# Adding to i
# 458
# RemainingCodebook Length 262
# [2, 9, 3, 5]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 459
# RemainingCodebook Length 261
# [7, 4, 3, 5]
# 460
# RemainingCodebook Length 260
# [4, 9, 5, 9]
# Adding to i
# 461
# RemainingCodebook Length 259
# [6, 8, 4, 9]
# 462
# RemainingCodebook Length 258
# [9, 1, 6, 7]
# 463
# RemainingCodebook Length 257
# [6, 2, 7, 6]
# 464
# RemainingCodebook Length 256
# [4, 3, 1, 8]
# Adding to i
# Adding to i
# 465
# RemainingCodebook Length 255
# [4, 1, 3, 8]
# Adding to i
# 466
# RemainingCodebook Length 254
# [2, 3, 5, 1]
# 467
# RemainingCodebook Length 253
# [4, 9, 4, 8]
# Adding to i
# Adding to i
# Adding to i
# 468
# RemainingCodebook Length 252
# [4, 9, 9, 4]
# 469
# RemainingCodebook Length 251
# [7, 4, 5, 7]
# Adding to i
# Adding to i
# 470
# RemainingCodebook Length 250
# [8, 1, 6, 6]
# 471
# RemainingCodebook Length 249
# [7, 6, 8, 3]
# 472
# RemainingCodebook Length 248
# [9, 8, 5, 4]
# Adding to i
# Adding to i
# 473
# RemainingCodebook Length 247
# [6, 2, 9, 8]
# 474
# RemainingCodebook Length 246
# [5, 1, 8, 5]
# Adding to i
# Adding to i
# 475
# RemainingCodebook Length 245
# [5, 9, 2, 7]
# Adding to i
# 476
# RemainingCodebook Length 244
# [6, 5, 5, 7]
# Adding to i
# Adding to i
# 477
# RemainingCodebook Length 243
# [8, 6, 5, 1]
# Adding to i
# 478
# RemainingCodebook Length 242
# [9, 8, 7, 6]
# 479
# RemainingCodebook Length 241
# [7, 9, 5, 3]
# 480
# RemainingCodebook Length 240
# [4, 1, 3, 8]
# Adding to i
# Adding to i
# Adding to i
# 481
# RemainingCodebook Length 239
# [3, 6, 3, 3]
# 482
# RemainingCodebook Length 238
# [4, 7, 5, 7]
# Adding to i
# 483
# RemainingCodebook Length 237
# [1, 8, 8, 8]
# 484
# RemainingCodebook Length 236
# [8, 4, 2, 5]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 485
# RemainingCodebook Length 235
# [6, 3, 5, 5]
# 486
# RemainingCodebook Length 234
# [8, 5, 3, 7]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 487
# RemainingCodebook Length 233
# [8, 9, 8, 7]
# 488
# RemainingCodebook Length 232
# [2, 1, 4, 7]
# Adding to i
# Adding to i
# 489
# RemainingCodebook Length 231
# [4, 1, 7, 3]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 490
# RemainingCodebook Length 230
# [7, 6, 7, 2]
# Adding to i
# 491
# RemainingCodebook Length 229
# [7, 6, 1, 5]
# Adding to i
# 492
# RemainingCodebook Length 228
# [9, 3, 7, 1]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 493
# RemainingCodebook Length 227
# [7, 3, 1, 2]
# 494
# RemainingCodebook Length 226
# [2, 2, 5, 9]
# 495
# RemainingCodebook Length 225
# [8, 9, 2, 1]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 496
# RemainingCodebook Length 224
# [8, 2, 6, 7]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 497
# RemainingCodebook Length 223
# [8, 5, 2, 6]
# Adding to i
# Adding to i
# 498
# RemainingCodebook Length 222
# [8, 1, 9, 9]
# 499
# RemainingCodebook Length 221
# [4, 3, 6, 4]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 500
# RemainingCodebook Length 220
# [4, 8, 5, 8]
# Adding to i
# 501
# RemainingCodebook Length 219
# [5, 3, 2, 1]
# 502
# RemainingCodebook Length 218
# [4, 6, 4, 5]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 503
# RemainingCodebook Length 217
# [5, 6, 3, 5]
# Adding to i
# 504
# RemainingCodebook Length 216
# [9, 6, 5, 2]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 505
# RemainingCodebook Length 215
# [9, 3, 4, 7]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 506
# RemainingCodebook Length 214
# [8, 8, 4, 2]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 507
# RemainingCodebook Length 213
# [8, 5, 2, 6]
# Adding to i
# Adding to i
# 508
# RemainingCodebook Length 212
# [2, 2, 2, 6]
# Adding to i
# Adding to i
# Adding to i
# 509
# RemainingCodebook Length 211
# [8, 8, 6, 4]
# 510
# RemainingCodebook Length 210
# [5, 5, 4, 5]
# Adding to i
# 511
# RemainingCodebook Length 209
# [5, 9, 4, 9]
# 512
# RemainingCodebook Length 208
# [2, 1, 3, 6]
# 513
# RemainingCodebook Length 207
# [3, 2, 2, 7]
# Adding to i
# 514
# RemainingCodebook Length 206
# [5, 6, 4, 6]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 515
# RemainingCodebook Length 205
# [5, 6, 6, 8]
# 516
# RemainingCodebook Length 204
# [7, 3, 5, 6]
# Adding to i
# Adding to i
# Adding to i
# 517
# RemainingCodebook Length 203
# [2, 2, 2, 6]
# Adding to i
# Adding to i
# 518
# RemainingCodebook Length 202
# [2, 6, 3, 2]
# 519
# RemainingCodebook Length 201
# [3, 3, 7, 4]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 520
# RemainingCodebook Length 200
# [8, 2, 7, 8]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 521
# RemainingCodebook Length 199
# [1, 9, 9, 1]
# Adding to i
# 522
# RemainingCodebook Length 198
# [9, 2, 7, 9]
# 523
# RemainingCodebook Length 197
# [5, 2, 4, 2]
# 524
# RemainingCodebook Length 196
# [6, 9, 9, 6]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 525
# RemainingCodebook Length 195
# [6, 4, 6, 7]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 526
# RemainingCodebook Length 194
# [6, 7, 9, 4]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 527
# RemainingCodebook Length 193
# [6, 7, 6, 1]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 528
# RemainingCodebook Length 192
# [1, 9, 6, 7]
# Adding to i
# 529
# RemainingCodebook Length 191
# [8, 7, 6, 3]
# 530
# RemainingCodebook Length 190
# [7, 9, 5, 3]
# Adding to i
# 531
# RemainingCodebook Length 189
# [7, 4, 2, 4]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 532
# RemainingCodebook Length 188
# [7, 9, 9, 7]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 533
# RemainingCodebook Length 187
# [9, 3, 4, 7]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 534
# RemainingCodebook Length 186
# [3, 4, 9, 7]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 535
# RemainingCodebook Length 185
# [9, 7, 6, 4]
# Adding to i
# Adding to i
# Adding to i
# 536
# RemainingCodebook Length 184
# [4, 4, 8, 7]
# Adding to i
# 537
# RemainingCodebook Length 183
# [4, 5, 9, 9]
# 538
# RemainingCodebook Length 182
# [9, 2, 5, 7]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 539
# RemainingCodebook Length 181
# [9, 9, 8, 8]
# Adding to i
# 540
# RemainingCodebook Length 180
# [1, 1, 3, 5]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 541
# RemainingCodebook Length 179
# [8, 5, 1, 5]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 542
# RemainingCodebook Length 178
# [7, 2, 1, 1]
# Adding to i
# Adding to i
# Adding to i
# 543
# RemainingCodebook Length 177
# [8, 4, 1, 4]
# Adding to i
# Adding to i
# Adding to i
# 544
# RemainingCodebook Length 176
# [3, 8, 3, 5]
# 545
# RemainingCodebook Length 175
# [2, 2, 6, 1]
# 546
# RemainingCodebook Length 174
# [7, 6, 8, 3]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 547
# RemainingCodebook Length 173
# [7, 7, 9, 5]
# Adding to i
# 548
# RemainingCodebook Length 172
# [5, 5, 2, 3]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 549
# RemainingCodebook Length 171
# [7, 6, 8, 3]
# Adding to i
# Adding to i
# 550
# RemainingCodebook Length 170
# [7, 6, 1, 5]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 551
# RemainingCodebook Length 169
# [7, 5, 1, 4]
# Adding to i
# Adding to i
# 552
# RemainingCodebook Length 168
# [8, 1, 9, 9]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 553
# RemainingCodebook Length 167
# [5, 3, 7, 6]
# Adding to i
# Adding to i
# Adding to i
# 554
# RemainingCodebook Length 166
# [2, 9, 1, 3]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 555
# RemainingCodebook Length 165
# [6, 6, 9, 3]
# 556
# RemainingCodebook Length 164
# [8, 9, 2, 1]
# Adding to i
# Adding to i
# 557
# RemainingCodebook Length 163
# [8, 5, 1, 5]
# Adding to i
# Adding to i
# Adding to i
# 558
# RemainingCodebook Length 162
# [8, 2, 1, 2]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 559
# RemainingCodebook Length 161
# [7, 5, 6, 9]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 560
# RemainingCodebook Length 160
# [5, 3, 8, 7]
# 561
# RemainingCodebook Length 159
# [1, 8, 1, 1]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 562
# RemainingCodebook Length 158
# [4, 5, 8, 8]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 563
# RemainingCodebook Length 157
# [3, 4, 1, 8]
# Adding to i
# 564
# RemainingCodebook Length 156
# [8, 7, 8, 5]
# 565
# RemainingCodebook Length 155
# [3, 9, 1, 4]
# Adding to i
# Adding to i
# 566
# RemainingCodebook Length 154
# [1, 1, 2, 4]
# 567
# RemainingCodebook Length 153
# [5, 6, 7, 9]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 568
# RemainingCodebook Length 152
# [3, 1, 5, 9]
# 569
# RemainingCodebook Length 151
# [8, 4, 9, 3]
# Adding to i
# 570
# RemainingCodebook Length 150
# [4, 9, 6, 1]
# Adding to i
# 571
# RemainingCodebook Length 149
# [5, 4, 4, 4]
# 572
# RemainingCodebook Length 148
# [8, 6, 3, 8]
# 573
# RemainingCodebook Length 147
# [1, 2, 7, 1]
# 574
# RemainingCodebook Length 146
# [2, 3, 6, 2]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 575
# RemainingCodebook Length 145
# [5, 5, 5, 6]
# 576
# RemainingCodebook Length 144
# [1, 9, 6, 7]
# Adding to i
# 577
# RemainingCodebook Length 143
# [2, 8, 9, 1]
# 578
# RemainingCodebook Length 142
# [8, 9, 8, 7]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 579
# RemainingCodebook Length 141
# [7, 9, 8, 6]
# Adding to i
# Adding to i
# 580
# RemainingCodebook Length 140
# [3, 8, 2, 4]
# Adding to i
# 581
# RemainingCodebook Length 139
# [4, 2, 7, 4]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 582
# RemainingCodebook Length 138
# [8, 2, 4, 5]
# Adding to i
# Adding to i
# 583
# RemainingCodebook Length 137
# [9, 9, 4, 4]
# Adding to i
# 584
# RemainingCodebook Length 136
# [1, 9, 4, 5]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 585
# RemainingCodebook Length 135
# [3, 4, 4, 2]
# Adding to i
# Adding to i
# 586
# RemainingCodebook Length 134
# [9, 6, 5, 2]
# Adding to i
# 587
# RemainingCodebook Length 133
# [9, 2, 5, 7]
# Adding to i
# Adding to i
# Adding to i
# 588
# RemainingCodebook Length 132
# [3, 5, 2, 1]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 589
# RemainingCodebook Length 131
# [8, 7, 4, 1]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 590
# RemainingCodebook Length 130
# [3, 1, 8, 3]
# Adding to i
# Adding to i
# 591
# RemainingCodebook Length 129
# [9, 1, 4, 5]
# 592
# RemainingCodebook Length 128
# [1, 2, 3, 6]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 593
# RemainingCodebook Length 127
# [1, 2, 7, 1]
# Adding to i
# 594
# RemainingCodebook Length 126
# [1, 6, 2, 9]
# 595
# RemainingCodebook Length 125
# [9, 4, 7, 2]
# Adding to i
# Adding to i
# 596
# RemainingCodebook Length 124
# [9, 8, 7, 6]
# Adding to i
# Adding to i
# Adding to i
# 597
# RemainingCodebook Length 123
# [9, 1, 5, 6]
# Adding to i
# Adding to i
# 598
# RemainingCodebook Length 122
# [3, 4, 8, 6]
# 599
# RemainingCodebook Length 121
# [2, 3, 5, 1]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 600
# RemainingCodebook Length 120
# [9, 2, 3, 5]
# Adding to i
# Adding to i
# 601
# RemainingCodebook Length 119
# [1, 5, 2, 8]
# Adding to i
# 602
# RemainingCodebook Length 118
# [4, 6, 4, 5]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 603
# RemainingCodebook Length 117
# [8, 6, 2, 7]
# Adding to i
# Adding to i
# 604
# RemainingCodebook Length 116
# [7, 6, 3, 7]
# Adding to i
# Adding to i
# 605
# RemainingCodebook Length 115
# [7, 4, 2, 4]
# Adding to i
# 606
# RemainingCodebook Length 114
# [9, 1, 5, 6]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 607
# RemainingCodebook Length 113
# [4, 8, 7, 1]
# Adding to i
# Adding to i
# 608
# RemainingCodebook Length 112
# [3, 6, 4, 4]
# 609
# RemainingCodebook Length 111
# [2, 7, 1, 1]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 610
# RemainingCodebook Length 110
# [4, 5, 1, 1]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 611
# RemainingCodebook Length 109
# [9, 2, 3, 5]
# Adding to i
# Adding to i
# Adding to i
# 612
# RemainingCodebook Length 108
# [8, 2, 8, 9]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# WARNING: Randomly assigning code word
# [1.0, 3.0, 2.0, 6.0, 'ENSMUSG00000013973']
# Empty DataFrame
# Columns: [hyb1, hyb2, hyb3, hyb4, Gene]
# Index: []
# 613
# RemainingCodebook Length 107
# [4, 6, 7, 8]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# WARNING: Randomly assigning code word
# [1.0, 3.0, 3.0, 7.0, 'ENSMUSG00000053553']
# Empty DataFrame
# Columns: [hyb1, hyb2, hyb3, hyb4, Gene]
# Index: []
# 614
# RemainingCodebook Length 106
# [8, 2, 8, 9]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# WARNING: Randomly assigning code word
# [1.0, 3.0, 6.0, 1.0, 'ENSMUSG00000039405']
# Empty DataFrame
# Columns: [hyb1, hyb2, hyb3, hyb4, Gene]
# Index: []
# 615
# RemainingCodebook Length 105
# [4, 9, 8, 3]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 616
# RemainingCodebook Length 104
# [8, 2, 9, 1]
# Adding to i
# 617
# RemainingCodebook Length 103
# [4, 9, 9, 4]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 618
# RemainingCodebook Length 102
# [9, 9, 1, 1]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 619
# RemainingCodebook Length 101
# [4, 8, 7, 1]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 620
# RemainingCodebook Length 100
# [6, 6, 7, 1]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 621
# RemainingCodebook Length 99
# [9, 2, 5, 7]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 622
# RemainingCodebook Length 98
# [3, 9, 4, 7]
# Adding to i
# Adding to i
# Adding to i
# 623
# RemainingCodebook Length 97
# [3, 4, 1, 8]
# Adding to i
# Adding to i
# Adding to i
# 624
# RemainingCodebook Length 96
# [9, 1, 6, 7]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 625
# RemainingCodebook Length 95
# [4, 3, 6, 4]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 626
# RemainingCodebook Length 94
# [9, 2, 1, 3]
# 627
# RemainingCodebook Length 93
# [3, 8, 7, 9]
# 628
# RemainingCodebook Length 92
# [4, 5, 5, 5]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 629
# RemainingCodebook Length 91
# [7, 5, 1, 4]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 630
# RemainingCodebook Length 90
# [8, 4, 1, 4]
# Adding to i
# 631
# RemainingCodebook Length 89
# [9, 9, 1, 1]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 632
# RemainingCodebook Length 88
# [9, 6, 8, 5]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 633
# RemainingCodebook Length 87
# [6, 6, 2, 5]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 634
# RemainingCodebook Length 86
# [8, 6, 1, 6]
# Adding to i
# Adding to i
# 635
# RemainingCodebook Length 85
# [7, 8, 1, 7]
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# Adding to i
# 636
# COMPLETED GENERATING CODEBOOK

# %% [markdown]
# #### 3. Checking Results

# %%
VerifyCodebook(Channel1Codebook)
# Out:
# Codebook has correct length and no repeats
# All genes are unique

# %%
'''
Inputs
Codebook - Pandas dataframe with gene name, under 'Gene', and codeword assigninment under 'hyb1', 'hyb2' etc.
FPKMS_table - Pandas dataframe containing the genes under 'gene_symbols', and the expression value under 'avg'.
numColors - Integer number of pseudocolors in codebook design.

Returns a pandas dataframe containing the average expression for each hybridization. Columns are each barcoding round, while each row represents the pseudocolor. 
'''

FinalFPKMS = FPKMSforCodebook(Channel1Codebook, Channel1FPKMS, 9)
FinalFPKMS
# Out:
#           hyb1         hyb2         hyb3         hyb4
# 1  8918.809878  8835.880757  8787.741483  8851.762409
# 2  8861.290372  8804.384146  8808.546926  8808.390003
# 3  8849.856409  8840.102942  8841.578330  8801.511324
# 4  8790.818898  8835.340419  8841.273122  8851.774883
# 5  8811.405771  8826.793243  8892.395211  8753.612601
# 6  8777.635651  8782.232906  8840.860454  8903.601922
# 7  8777.798596  8839.656434  8840.680810  8851.267372
# 8  8819.456964  8837.522527  8789.715166  8800.766530
# 9  8826.468218  8831.627382  8790.749256  8810.853713

# %% [markdown]
# ### 4. Save Codebook

# %%
Channel1Codebook.to_csv('put_your_path_here', index= False)

# %%
FinalFPKMS.to_csv('your_path')
