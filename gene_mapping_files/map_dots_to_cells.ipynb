# %%
import numpy as np
import pandas as pd
import tifffile as tf
import matplotlib.pyplot as plt
from pathlib import Path
from map_genes import keep_dots_in_cells

# %% [markdown]
# # Test

# %%
#test function
mask = '/groups/CaiLab/personal/Lex/raw/Linus_10k_cleared_080918_NIH3T3/notebook_pyfiles/edges_deleted/MMStack_Pos0.tif'
for i in range(11):
    dot_locations = f'/groups/CaiLab/personal/Lex/raw/Linus_10k_cleared_080918_NIH3T3/notebook_pyfiles/decoded/Threshold_{i}/diff_1_minseed_3_z_0_finalgenes.csv'
    keep_dots_in_cells(mask, dot_locations)
# Out:
# /groups/CaiLab/personal/Lex/raw/Linus_10k_cleared_080918_NIH3T3/notebook_pyfiles/decoded/genes_in_cells/Threshold_0/gene_locations.csv
# /groups/CaiLab/personal/Lex/raw/Linus_10k_cleared_080918_NIH3T3/notebook_pyfiles/decoded/genes_in_cells/Threshold_1/gene_locations.csv
# /groups/CaiLab/personal/Lex/raw/Linus_10k_cleared_080918_NIH3T3/notebook_pyfiles/decoded/genes_in_cells/Threshold_2/gene_locations.csv
# /groups/CaiLab/personal/Lex/raw/Linus_10k_cleared_080918_NIH3T3/notebook_pyfiles/decoded/genes_in_cells/Threshold_3/gene_locations.csv
# /groups/CaiLab/personal/Lex/raw/Linus_10k_cleared_080918_NIH3T3/notebook_pyfiles/decoded/genes_in_cells/Threshold_4/gene_locations.csv
# /groups/CaiLab/personal/Lex/raw/Linus_10k_cleared_080918_NIH3T3/notebook_pyfiles/decoded/genes_in_cells/Threshold_5/gene_locations.csv
# /groups/CaiLab/personal/Lex/raw/Linus_10k_cleared_080918_NIH3T3/notebook_pyfiles/decoded/genes_in_cells/Threshold_6/gene_locations.csv
# ...

# %%
#read in output
dots = pd.read_csv(
    "/groups/CaiLab/personal/Lex/raw/Linus_10k_cleared_080918_NIH3T3/notebook_pyfiles/decoded/genes_in_cells/Threshold_0/gene_locations.csv", 
    index_col = 0)

# %%
#look
dots
# Out:
#         Unnamed: 0.1          genes            x            y    z  \
# 3                  3  1700022a21rik   630.975331   265.664189  0.0
# 7                  7  1700022a21rik   704.087036   551.238359  0.0
# 11                11  1700022a21rik  1677.469931  1279.589393  0.0
# 12                12  1700022a21rik  1435.970692   551.782363  0.0
# 18                18  1700025g04rik  1589.251460  1739.911367  0.0
# ...              ...            ...          ...          ...  ...
# 112555        112555        fake998   579.795787   735.248408  0.0
# 112563        112563        fake999   856.205126  1662.676317  0.0
# 112564        112564        fake999  1650.922862  1223.454140  0.0
# 112565        112565        fake999  1412.795957  1356.711958  0.0
# 112568        112568        fake999  1259.921397   206.519496  0.0
#
#           intensity       area  ambiguity score  cell number
# 3        247.333333  13.333333                2            4
# ...

# %%
#read in image (c,y,x)
image = tf.imread(mask)

# %%
plt.rcParams["figure.figsize"] = (5,5)
plt.imshow(image, cmap = "gray")

# %%
#overal dots on mask
plt.imshow(image, cmap = "gray")
plt.scatter(dots["x"],dots["y"], c = "blue", s = 0.01)

# %% [markdown]
# # Do all images

# %%
# #paths for decoded genes and mask
# decoded_genes = []
# mask_paths = []
# for i in range(168):
#     decoded_genes.append(f'/groups/CaiLab/personal/Lex/raw/20k_dash_063021_3t3/notebook_pyfiles/decoded/Pos_{i}/pre_seg_diff_1_minseeds_3_filtered.csv')
#     mask_paths.append(f'/groups/CaiLab/personal/Lex/raw/20k_dash_063021_3t3/notebook_pyfiles/edges_deleted/MMStack_Pos{i}.tif')

# %%
# keep_dots_parallel(mask_paths,decoded_genes)

# %% [markdown]
# # Check an image

# %%
# mask = '/groups/CaiLab/personal/Lex/raw/20k_dash_063021_3t3/notebook_pyfiles/edges_deleted/MMStack_Pos2.tif'
# #read in image (c,y,x)
# image = tf.imread(mask)

# %%
# #read in output
# dots = pd.read_csv("/groups/CaiLab/personal/Lex/raw/20k_dash_063021_3t3/notebook_pyfiles/decoded/genes_in_cells/Pos_2/gene_locations.csv", index_col = 0)

# %%
# plt.rcParams["figure.figsize"] = (5,5)
# plt.imshow(image, cmap = "gray")

# %%
# #overal dots on mask
# plt.imshow(image, cmap = "gray")
# plt.scatter(dots["x"],dots["y"], c = "blue", s = 0.01)

# %% [markdown]
# It looks like it performed it perfectly.
